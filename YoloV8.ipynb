# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from ultralytics import YOLO
from PIL import Image

# %%
YNet = YOLO("yolov8n.pt")

# %%
YNet.predict(source="/content/dogs.jpg",save=True,conf=0.5,save_txt=True)
# Out:
# image 1/1 /content/dogs.jpg: 384x640 2 dogs, 315.2ms
# Speed: 5.6ms preprocess, 315.2ms inference, 39.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 1 label saved to runs/detect/predict/labels
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
img = Image.open("/content/dogs.jpg")
img.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F35FDFB8940>

# %%
# Image after running Yolov8 on it (Two objects(Dogs) detected)
img_det = Image.open("/content/runs/detect/predict/dogs.jpg")
img_det.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F35FDFB8850>
